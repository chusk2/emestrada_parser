# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
add_df = pd.read_csv('classified_json_files/classified_exercises.csv')

# %%
df.head()
# Out:
#   subject  year                      topic       exam  \
# 0  Física  2016  Física cuántica y nuclear      Junio
# 1  Física  2016  Física cuántica y nuclear      Junio
# 2  Física  2016  Física cuántica y nuclear  Reserva 2
# 3  Física  2016  Física cuántica y nuclear  Reserva 3
# 4  Física  2016  Física cuántica y nuclear  Reserva 4
#
#                            exercise   exercise_type  \
# 0      JUNIO. EJERCICIO 2. OPCIÓN B  no clasificado
# 1      JUNIO. EJERCICIO 4. OPCIÓN A  no clasificado
# 2  RESERVA 2. EJERCICIO 4. OPCIÓN A  no clasificado
# 3  RESERVA 3. EJERCICIO 2. OPCIÓN A  no clasificado
# 4  RESERVA 4. EJERCICIO 2. OPCIÓN A  no clasificado
#
#                                            statement
# 0  a) Teoría de Einstein del efecto fotoeléctrico...
# 1  El * Pb emite dos partículas beta y se transfo...
# 2  a) Calcule la energía liberada en el proceso p...
# 3  a) ¿Qué se entiende por dualidad onda-corpúscu...
# 4  a) Escriba la ley de desintegración radiactiva...

# %%
add_df
# Out:
#     subject  year               topic                     exam  \
# 0   QUÍMICA  2020  EQUILIBRIO QUÍMICO      Junio, Ejercicio B2
# 1   QUÍMICA  2020  EQUILIBRIO QUÍMICO      Junio, Ejercicio C1
# 2   QUÍMICA  2020  EQUILIBRIO QUÍMICO      Junio, Ejercicio C1
# 3   QUÍMICA  2020  EQUILIBRIO QUÍMICO  Reserva 1, Ejercicio C1
# 4   QUÍMICA  2020  EQUILIBRIO QUÍMICO  Reserva 1, Ejercicio C1
# ..      ...   ...                 ...                      ...
# 70  QUIMICA  2025  EQUILIBRIO QUÍMICO      Junio, Ejercicio 2B
# 71  QUIMICA  2025  EQUILIBRIO QUÍMICO      Junio, Ejercicio 3A
# 72  QUIMICA  2025  EQUILIBRIO QUÍMICO  Reserva 1, Ejercicio 2A
# 73  QUIMICA  2025  EQUILIBRIO QUÍMICO  Reserva 2, Ejercicio 2B
# 74  QUIMICA  2025  EQUILIBRIO QUÍMICO      Julio, Ejercicio 3A
#
#                         type
# 0   Principio de LeChatelier
# 1            Concentraciones
# 2                     Kc, Kp
# 3            Concentraciones
# 4                     Kc, Kp
# ..                       ...
# 70                  Cinética
# 71    Equilibrio heterogéneo
# 72  Principio de LeChatelier
# 73                  Cinética
# 74                    Kc, Kp
#
# [75 rows x 5 columns]

# %%
def form_exercise_string(row):
    # exam = [row['exam'].upper() ]
    exercise = [i.upper() for i in row['exam'].split(', ')]
    return '. '.join(exercise)

# %%
add_df['exercise'] = add_df.apply(form_exercise_string, axis = 1)

# %%
add_df['exam'] = add_df['exam'].apply(lambda x : x.split(', ')[0])

# %%
add_df.rename(columns = {'type' : 'exercise_type'}, inplace=True)

# %%
add_df['statement'] = None

# %%
# subject,year,topic,exam,exercise_number,statement,exercise_type
add_df = add_df[['subject', 'year', 'topic', 'exam', 'exercise', 'exercise_type', 'statement']]

# %%
add_df.head()
# Out:
#    subject  year               topic       exam                 exercise  \
# 0  QUÍMICA  2020  EQUILIBRIO QUÍMICO      Junio      JUNIO. EJERCICIO B2
# 1  QUÍMICA  2020  EQUILIBRIO QUÍMICO      Junio      JUNIO. EJERCICIO C1
# 2  QUÍMICA  2020  EQUILIBRIO QUÍMICO      Junio      JUNIO. EJERCICIO C1
# 3  QUÍMICA  2020  EQUILIBRIO QUÍMICO  Reserva 1  RESERVA 1. EJERCICIO C1
# 4  QUÍMICA  2020  EQUILIBRIO QUÍMICO  Reserva 1  RESERVA 1. EJERCICIO C1
#
#               exercise_type statement
# 0  Principio de LeChatelier      None
# 1           Concentraciones      None
# 2                    Kc, Kp      None
# 3           Concentraciones      None
# 4                    Kc, Kp      None

# %%
df.head()
# Out:
#   subject  year                      topic       exam  \
# 0  Física  2016  Física cuántica y nuclear      Junio
# 1  Física  2016  Física cuántica y nuclear      Junio
# 2  Física  2016  Física cuántica y nuclear  Reserva 2
# 3  Física  2016  Física cuántica y nuclear  Reserva 3
# 4  Física  2016  Física cuántica y nuclear  Reserva 4
#
#                            exercise   exercise_type  \
# 0      JUNIO. EJERCICIO 2. OPCIÓN B  no clasificado
# 1      JUNIO. EJERCICIO 4. OPCIÓN A  no clasificado
# 2  RESERVA 2. EJERCICIO 4. OPCIÓN A  no clasificado
# 3  RESERVA 3. EJERCICIO 2. OPCIÓN A  no clasificado
# 4  RESERVA 4. EJERCICIO 2. OPCIÓN A  no clasificado
#
#                                            statement
# 0  a) Teoría de Einstein del efecto fotoeléctrico...
# 1  El * Pb emite dos partículas beta y se transfo...
# 2  a) Calcule la energía liberada en el proceso p...
# 3  a) ¿Qué se entiende por dualidad onda-corpúscu...
# 4  a) Escriba la ley de desintegración radiactiva...

# %%
df = pd.concat([df, add_df])

# %%
df.to_csv('data.csv', index = False)
